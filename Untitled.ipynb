# %%
import pandas as pd

data = pd.read_csv('your_file.csv')
data.head()

# %%
for i in range(3):
    print(1+1)
print(1+1) 
print(1+1)
print(1+1)
print(1+1)

# %%
for i in range(3):
    print(1+1)

# %%
print(1+1)
